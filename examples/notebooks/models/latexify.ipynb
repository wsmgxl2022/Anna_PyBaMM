# %% [markdown]
# # Using latexify in PyBaMM
# In this notebook we show how to use `latexify` to print all the model equations.

# %% [markdown]
# First we import pybamm

# %%
# %pip install pybamm -q    # install PyBaMM if it is not installed
import pybamm
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Then we load a model

# %%
model = pybamm.lithium_ion.SPMe()

# %% [markdown]
# Now that we have defined a model we can use latexify to get the latex of all the model equations

# %%
model.latexify()
# Out:
# \large{\underline{\textbf{Single Particle Model with electrolyte Equations}}}\
# \\\\\ \textbf{Discharge capacity [A.h]}\\\\\frac{d}{d t} Q_{Ah} = \frac{\hat{I
# } \tau}{3600}\\\\Q_{Ah} = 0.0\quad at\; t=0\\\\\\ \textbf{X-averaged negative
# particle concentration}\\\\\frac{\partial}{\partial t} \bar{c}_{s\,n} = \frac{
# \nabla\cdot \left(\frac{D_{n} \left(\nabla \bar{c}_{s\,n}\right)}{\hat{D}_{}}\
# right)}{C_{diff n}}\quad 0 < r < 1\\\\\bar{c}_{s\,n} = \int c_{n}_{s\,n} = 0.0
# \quad r = 0\\\\\frac{\partial}{\partial r} \bar{c}_{s\,n} = - \frac{0.33333333
# 3333333 C_{diff n} I a_{n}_{}\, dxn}{\frac{D_{n}}{\hat{D}_{}}_{R\,n} l_{n} \in
# t \epsilon_{s n}\, dxn}\quad r = 1\\\\\\ \textbf{X-averaged positive particle
# concentration}\\\\\frac{\partial}{\partial t} \bar{c}_{s\,p} = \frac{\nabla\cd
# ot \left(\frac{D_{p} \left(\nabla \bar{c}_{s\,p}\right)}{\hat{D}_{}}\right)}{C
# _{diff p}}\quad 0 < r < 1\\\\\bar{c}_{s\,p} = \int c_{p}_{s\,p} = 0.0\quad r =
#  0\\\\\frac{\partial}{\partial r} \bar{c}_{s\,p} = \frac{0.333333333333333 C_{
# diff p} I a_{p}_{}\, dxn}{\frac{D_{p}}{\hat{D}_{}}_{p} a_{R\,p} l_{p} \int \ep
# silon_{s p}\, dxn}\quad r = 1\\\\\\ \textbf{Porosity times concentration(Negat
# ive electrode porosity times concentration, Separator porosity times concentra
# tion, Positive electrode porosity times concentration)}\\\\\frac{\partial}{\pa
# rtial t} \epsilon{c_e} = \frac{a}{\gamma_{e}} - \frac{\nabla\cdot \left(\frac{
# C_{e} i_{e} t_{plus}}{\gamma_{e}} - \frac{D_{e} \epsilon_e} \left(\nabla c_{e}
# \right)}{D_{e}_{e}}\quad 0 < x < 1\\\\\left[ a = \begin{cases}\frac{3.0 \epsil
# on_{s n} j_{n}}{\hat{R}_{} a_{n}_n}} < l_n \\ 0.0& l_n < \mathtt{\text{x\_s}}
# < l_n + l_s \\ \frac{3.0 \epsilon_{s p} j_{p}}{\hat{R}_{} a_{p}_n + l_s < \mat
# htt{\text{x\_p}} < 1\end{cases}, \  i_{e} = \begin{cases}\frac{I x_{n}}{l_{n}}
# & 0 < \mathtt{\text{x\_n}} < l_n \\ I& l_n < \mathtt{\text{x\_s}} < l_n + l_s
# \\ \frac{- I x_{p} + I}{l_{p}}& l_n + l_s < \mathtt{\text{x\_p}} < 1\end{cases
# }, \  c_{e} = \begin{cases}\frac{\epsilon_{c e n}}{\epsilon_{n}_n}} < l_n \\ \
# frac{\epsilon_{c e s}}{\epsilon_{s}_n < \mathtt{\text{x\_s}} < l_n + l_s \\ \f
# rac{\epsilon_{c e p}}{\epsilon_{p}_n + l_s < \mathtt{\text{x\_p}} < 1\end{case
# s}, \  \epsilon_e} = \begin{cases}\left(\epsilon_{n}_{e n}}& 0 < \mathtt{\text
# {x\_n}} < l_n \\ \left(\epsilon_{s}_{e s}}& l_n < \mathtt{\text{x\_s}} < l_n +
#  l_s \\ \left(\epsilon_{p}_{e p}}& l_n + l_s < \mathtt{\text{x\_p}} < 1\end{ca
# ses}\right]\\\\\epsilon{c_e} = \epsilon{}_{e}_{x} l_{p}}{\frac{RT_{p} \int \ep
# silon_{s p}_{s p}}\, dxn} - \frac{I I{}_{x} \left(x_{p} + \frac{0.5 \left(x_{p
# } - 1.0\right)_{p}}\right)}{\frac{RT_{p} \int \epsilon_{s p}_{s p}}\, dxn} + \
# frac{I I{}_{x}}{\frac{RT_{p} \int \epsilon_{s p}_{s p}}\, dxn} + \int \left(\f
# rac{\left(2.0 \frac{1}{\hat{T}_{amb} - T{}_{p} j_{scale p}}{j{p}_{p}} + \frac{
# U_{p} - U_{p}_{p}}{dT} \left(T_{amb} - T{}_{s\,p}_{s\,p}_{plus}\right) \left(\
# frac{1}{\hat{T}_{amb} - T{}_{c e p}}{\epsilon_{p}_{e}\, dxn}\right) \right)} +
#  \frac{9309419314.30671 C_{e} D_{e}_{concentration scale} l_{n}}{R T{}_{e} \ka
# ppa_{e} \int \left(\epsilon_{s}_{e s}}\, dxn} - \frac{3103139771.43557 C_{e} D
# _{e}_{concentration scale} l_{n}}{R T{}_{e} \kappa_{e} \int \left(\epsilon_{n}
# _{e n}}\, dxn} - \frac{9309419314.30671 C_{e} D_{e}_{concentration scale} \lef
# t(- I l_{p} + I\right)}{R T{}_{e} \kappa_{e} \int \left(\epsilon_{s}_{e s}}\,
# dxn} - \left(1+\frac{dlnf}{dlnc} \frac{1}{\hat{T}_{plus}\right) \left(T_{amb}
# - T{}_{plus}\right)\right) \int \log{\left(\max\left(1.0 \cdot 10_{c e n}}{\ep
# silon_{n}_{e}\, dxn}\right) \right)}\, dxn + \int \frac{0.5 I I{}_{x} \left(-
# 2.0 l_{n} x_{n} + x_{n}_{n} l_{n} \int \epsilon_{s n}_{s n}}\, dxn}\, dxn - \i
# nt \left(\frac{\left(2.0 \frac{1}{\hat{T}_{amb} - T{}_{n} j_{scale n}}{j{n}_{n
# }} + \frac{U_{n} - U_{n}_{n}}{dT} \left(T_{amb} - T{}_{s\,n}_{s\,n}_{e} D_{e}_
# {concentration scale} \left(l_{p}_{p}_{p}\right)}{R T{}_{e} \kappa_{e} \int \l
# eft(\epsilon_{p}_{e p}}\, dxn} - \frac{9309419314.30671 C_{e} D_{e}_{concentra
# tion scale}}{R T{}_{e} \kappa_{e} \int \left(\epsilon_{p}_{e p}}\, dxn}\right)
# }{l_{p}}\right)\, dxn_{x} particle_{concentration scale n}}{I{}_{cc} n_{electr
# odes parallel}}\\\\A_{cc} = L_{y} L_{z}\\\\L_{x} = L_{n} + L_{p} + L_{s}\\\\C_
# {diff n} = \frac{\tau_{diffusion n}}{\tau}\\\\\tau_{diffusion n} = \frac{\left
# (R_{n}_{}}\\\\R_{n}_{n}\, dxn\, dxn\\\\C_{diff p} = \frac{\tau_{diffusion p}}{
# \tau}\\\\\tau_{diffusion p} = \frac{\left(R_{p}_{}}\\\\R_{p}_{p}\, dxn\, dxn\\
# \\\gamma_{e} = \frac{electrolyte_{concentration scale}}{particle_{concentratio
# n scale n}}\\\\a = \begin{cases}\frac{3.0 \epsilon_{s n} j_{n}}{\hat{R}_{} a_{
# n}_{s p} j_{p}}{\hat{R}_{} a_{p}_{p} = - \frac{0.333333333333333 I a_{p}_{}\,
# dxn}{l_{p} \int \epsilon_{s p}\, dxn}\\\\a_{p}_{s p}\, dxn\, dxn}{R_{p}_{p} =
# \frac{L_{p}}{L_{x}}\\\\I = \frac{\hat{I} \operatorname{sign}{\left(I{}_{n} = \
# frac{0.333333333333333 I a_{n}_{}\, dxn}{l_{n} \int \epsilon_{s n}\, dxn}\\\\a
# _{n}_{s n}\, dxn\, dxn}{R_{n}_{n} = \frac{L_{n}}{L_{x}}\\\\C_{e} = \frac{\tau_
# {diffusion e}}{\tau}\\\\\tau_{diffusion e} = \frac{L_{x}_{e}_{e} = \begin{case
# s}\frac{I x_{n}}{l_{n}}\\I\\\frac{- I x_{p} + I}{l_{p}}\end{cases}\\\\c_{e} =
# \begin{cases}\frac{\epsilon_{c e n}}{\epsilon_{n}_{c e s}}{\epsilon_{s}_{c e p
# }}{\epsilon_{p}_e} = \begin{cases}\left(\epsilon_{n}_{e n}}\\\left(\epsilon_{s
# }_{e s}}\\\left(\epsilon_{p}_{e p}}\end{cases}\\\\L_{z} = \text{Electrode heig
# ht [m]}\\\\L_{y} = \text{Electrode width [m]}\\\\n_{electrodes parallel} = \te
# xt{Number of electrodes connected in parallel to make a cell}\\\\I{}_{p} = \te
# xt{Positive electrode thickness [m]}\\\\L_{s} = \text{Separator thickness [m]}
# \\\\L_{n} = \text{Negative electrode thickness [m]}\\\\particle_{concentration
#  scale n} = \text{Maximum concentration in negative electrode [mol.m-3]}\\\\F
# = \text{96485.33212}\\\\\hat{I} = \text{Current function [A]}\\\\\bar{c}_{s\,n
# } = \text{X-averaged negative particle concentration}\\\\\hat{D}_{} = \text{Ne
# gative electrode diffusivity [m2.s-1]}\\\\T{}_{n} = \text{Negative electrode d
# iffusivity [m2.s-1]}\\\\T_{amb} = \text{Ambient temperature [K]}\\\\R_{n} = \t
# ext{Negative particle radius [m]}\\\\\bar{c}_{s\,p} = \text{X-averaged positiv
# e particle concentration}\\\\\hat{D}_{} = \text{Positive electrode diffusivity
#  [m2.s-1]}\\\\D_{p} = \text{Positive electrode diffusivity [m2.s-1]}\\\\R_{p}
# = \text{Positive particle radius [m]}\\\\electrolyte_{concentration scale} = \
# text{Typical electrolyte concentration [mol.m-3]}\\\\\epsilon_{s p} = \text{Po
# sitive electrode active material volume fraction}\\\\\hat{R}_{} = \text{Positi
# ve particle radius [m]}\\\\\epsilon_{s n} = \text{Negative electrode active ma
# terial volume fraction}\\\\\hat{R}_{} = \text{Negative particle radius [m]}\\\
# \D_{e}_{plus} = \text{Cation transference number}\\\\\epsilon_{p}_{c e p} = \t
# ext{Positive electrode porosity times concentration}\\\\\epsilon_{s}_{c e s} =
#  \text{Separator porosity times concentration}\\\\\epsilon_{n}_{c e n} = \text
# {Negative electrode porosity times concentration}\\\\D_{e} = \text{Electrolyte
#  diffusivity [m2.s-1]}\\\\b_{e p} = \text{Positive electrode Bruggeman coeffic
# ient (electrolyte)}\\\\b_{e s} = \text{Separator Bruggeman coefficient (electr
# olyte)}\\\\b_{e n} = \text{Negative electrode Bruggeman coefficient (electroly
# te)}__{init}\, dxn\quad at\; t=0\\\\\frac{\partial}{\partial r} \bar{c}__{typ}
#  \int \hat{R}__{surf} a__{init}\, dxn\quad at\; t=0\\\\\frac{\partial}{\partia
# l r} \bar{c}__{typ} \int \hat{R}__{surf} \gamma__{b__{typ}}\right)}{C__{typ}}&
#  0 < \mathtt{\text{x\__{typ}}& l__{init}}& 0 < \mathtt{\text{x\__{init}}& l__{
# init}}& l__{b__{init}\right)__{b__{init}\right)__{b__{init}\right)__{b__{init}
#  c__{init}\quad at\; t=0\\\\\\ \textbf{Terminal voltage [V]}\\\\V = - \frac{0.
# 333333333333333 I I{}__{typ} L__{ref}}{F} \sigma__{b__{typ} L__{2.0}}{l__{ref}
# }{F} \sigma__{b__{typ} L__{ref}}{F} \sigma__{b__{ref}} \left(T__{ref}\right) +
#  2.0\right) \operatorname{asinh}{\left(\frac{0.5 j__{0}} \right)}}{ne__{ref} +
#  \frac{dU__{ref}\right) + \frac{1.0 \cdot 10__{-6}}{\max\left(1.0 \cdot 10__{-
# 10}, \min\left(0.9999999999, \bar{c}__{surf}\right)\right)} + \frac{1.0 \cdot
# 10__{-6}}{\max\left(1.0 \cdot 10__{-10}, \min\left(0.9999999999, \bar{c}__{sur
# f}\right)\right) - 1.0}}{\frac{RT__{ref}}{F}}\right)\, dxn + \int \left(1+\fra
# c{dlnf}{dlnc} \left(2.0 - 2.0 t__{ref}} \left(T__{ref}\right) + 1.0\right) \lo
# g{\left(\max\left(1.0 \cdot 10__{-15}, \frac{\epsilon__{init} \int c__{typ} I
# electrolyte__{ref} \gamma__{init}\right)__{b__{typ} I electrolyte__{ref} \gamm
# a__{init}\right)__{b__{typ} electrolyte__{ref} \gamma__{init}\right)__{b__{ref
# }} \left(2.0 - 2.0 t__{ref}\right) + 1+\frac{dlnf}{dlnc} \left(2.0 - 2.0 t__{-
# 15}, \frac{\epsilon__{init} \int c__{typ} L__{2}\right)}{\frac{RT__{ref}}{F} \
# sigma__{b__{ref}} \left(T__{ref}\right) + 2.0\right) \operatorname{asinh}{\lef
# t(\frac{0.5 j__{0}} \right)}}{ne__{ref} + \frac{dU__{ref}\right) + \frac{1.0 \
# cdot 10__{-6}}{\max\left(1.0 \cdot 10__{-10}, \min\left(0.9999999999, \bar{c}_
# _{surf}\right)\right)} + \frac{1.0 \cdot 10__{-6}}{\max\left(1.0 \cdot 10__{-1
# 0}, \min\left(0.9999999999, \bar{c}__{surf}\right)\right) - 1.0}}{\frac{RT__{r
# ef}}{F}}\right)\, dxn - \frac{0.5 \cdot \left(\frac{9309419314.30671 C__{typ}
# I electrolyte__{2.0} - x__{2} + 2.0 x__{ref} \gamma__{init}\right)__{b__{typ}
# I electrolyte__{ref} \gamma__{init}\right)__{b__{\mathtt{\text{right}}} \frac{
# RT__{ref}}{F} + ocv{}__{ref}\\\\\\ \textbf{Parameters and Variables}\\\\\tau =
#  \frac{F L__{typ}}\\\\I{}__{typ} = \frac{I{}__{typ}}{A__{typ}\right)__{2.0}}{\
# hat{D}__{typ} = \iint R__{typ}\right)__{2.0}}{\hat{D}__{typ} = \iint R__{typ}}
# \\0.0\\\frac{3.0 \epsilon__{typ}}\end{cases}\\\\j__{typ} \int \hat{R}__{typ} =
#  \frac{3.0 \iint \epsilon__{typ}}\\\\l__{typ} \right)}}{I{}__{typ}}\\\\j__{typ
# } \int \hat{R}__{typ} = \frac{3.0 \iint \epsilon__{typ}}\\\\l__{2.0}}{D__{typ}
# }\\\\i__{init}}\\\frac{\epsilon__{init}}\\\frac{\epsilon__{init}}\end{cases}\\
# \\\epsilon__{b__{init}\right)__{b__{init}\right)__{b__{init}\right)__{b__{typ}
#  = \text{Typical current [A]}\\\\L__{ref} = \text{Reference temperature [K]}\\
# \\D__{typ} = \text{Electrolyte diffusivity [m2.s-1]}\\\\t__{init} = \text{Posi
# tive electrode porosity}\\\\\epsilon__{init} = \text{Separator porosity}\\\\\e
# psilon__{init} = \text{Negative electrode porosity}\\\\\epsilon

# %% [markdown]
# We can also get a list of all the equations instead of a single line joined by newline

# %%
model.latexify(newline=False)
# Out:
# ⎡
# ⎢\large{\underline{\textbf{Single Particle Model with electrolyte Equations}}}
# ⎣
#
#                                         d          \hat{I}⋅\tau
# , \\ \textbf{Discharge capacity [A.h]}, ──(Q_Ah) = ────────────, Q_{Ah} = 0.0\
#                                         dt             3600
#
#                                                                        d
# quad at\; t=0, \\ \textbf{X-averaged negative particle concentration}, ──(\bar
#                                                                        dt
#
#
# {c}_{s\,n}) = \frac{\nabla\cdot \left(\frac{D_{n} \left(\nabla \bar{c}_{s\,n}\
#
#
#
# right)}{\hat{D}_{}}\right)}{C_{diff n}}\quad 0 < r < 1, \bar{c}_{s\,n} = \int
#
#
#                                    d                                    d
# c_{n}__{init}\, dxn\quad at\; t=0, ──(\bar{c}_{s\,n}) = 0.0\quad r = 0, ──(\ba
#                                    dr                                   dr
#
#
# r{c}_{s\,n}) = - \frac{0.333333333333333 C_{diff n} I a_{n}_{}\, dxn}{\frac{D_
#
#
#
# {n}}{\hat{D}_{}}_{R\,n} l_{n} \int \epsilon_{s n}\, dxn}\quad r = 1__{typ} \in
#
#
#                                                                              d
# t \hat{R}__{surf} a, \\ \textbf{X-averaged positive particle concentration}, ─
#                                                                              d
#
#
# ─(\bar{c}_{s\,p}) = \frac{\nabla\cdot \left(\frac{D_{p} \left(\nabla \bar{c}_{
# t
#
#
# s\,p}\right)}{\hat{D}_{}}\right)}{C_{diff p}}\quad 0 < r < 1, \bar{c}_{s\,p} =
#
#
#                                          d
#  \int c_{p}__{init}\, dxn\quad at\; t=0, ──(\bar{c}_{s\,p}) = 0.0\quad r = 0,
#                                          dr
#
# d
# ──(\bar{c}_{s\,p}) = \frac{0.333333333333333 C_{diff p} I a_{p}_{}\, dxn}{\fra
# dr
#
#
# c{D_{p}}{\hat{D}_{}}_{p} a_{R\,p} l_{p} \int \epsilon_{s p}\, dxn}\quad r = 1_
#
#
#
# _{typ} \int \hat{R}__{surf} \gamma, \\ \textbf{Porosity times concentration(Ne
#
#
#
# gative electrode porosity times concentration, Separator porosity times concen
#
#
#                                                             d
# tration, Positive electrode porosity times concentration)}, ──(\epsilon{c_e})
#                                                             dt
#
#
# = \frac{a}{\gamma_{e}} - \frac{\nabla\cdot \left(\frac{C_{e} i_{e} t_{plus}}{\
#
#
#
# gamma_{e}} - \frac{D_{e} \epsilon_e} \left(\nabla c_{e}\right)}{D_{e}_{e}}\qua
#
#
#
# d 0 < x < 1__{b__{typ}}\right)}{C, [a = \begin{cases}\frac{3.0 \epsilon_{s n}
#
#
#
# j_{n}}{\hat{R}_{} a_{n}_n}} < l_n \\ 0.0& l_n < \mathtt{\text{x\_s}} < l_n + l
#
#
#
# _s \\ \frac{3.0 \epsilon_{s p} j_{p}}{\hat{R}_{} a_{p}_n + l_s < \mathtt{\text
#
#
#
# {x\_p}} < 1\end{cases}__{typ}}& 0 < \mathtt{\text{x\__{typ}}& l, iₑ = \begin{c
#
#
#
# ases}\frac{I x_{n}}{l_{n}}& 0 < \mathtt{\text{x\_n}} < l_n \\ I& l_n < \mathtt
#
#
#
# {\text{x\_s}} < l_n + l_s \\ \frac{- I x_{p} + I}{l_{p}}& l_n + l_s < \mathtt{
#
#
#
# \text{x\_p}} < 1\end{cases}, cₑ = \begin{cases}\frac{\epsilon_{c e n}}{\epsilo
#
#
#
# n_{n}_n}} < l_n \\ \frac{\epsilon_{c e s}}{\epsilon_{s}_n < \mathtt{\text{x\_s
#
#
#
# }} < l_n + l_s \\ \frac{\epsilon_{c e p}}{\epsilon_{p}_n + l_s < \mathtt{\text
#
#
#
# {x\_p}} < 1\end{cases}__{init}}& 0 < \mathtt{\text{x\__{init}}& l__{init}}& l,
#
#
#
#  \epsilon_e}__{b = \begin{cases}\left(\epsilon_{n}_{e n}}& 0 < \mathtt{\text{x
#
#
#
# \_n}} < l_n \\ \left(\epsilon_{s}_{e s}}& l_n < \mathtt{\text{x\_s}} < l_n + l
#
#
#
# _s \\ \left(\epsilon_{p}_{e p}}& l_n + l_s < \mathtt{\text{x\_p}} < 1\end{case
#
#
#
# s}__{init}\right)__{b__{init}\right)__{b__{init}\right)__{b], \epsilon{c_e} =
#
#
#
# \epsilon{}_{e}__{init} c__{init}\quad at\; t=0, \\ \textbf{Terminal voltage [V
#
#
#
# ]}, V = - \frac{0.333333333333333 I I{}_{x} l_{p}}{\frac{RT_{p} \int \epsilon_
#
#
#
# {s p}_{s p}}\, dxn} - \frac{I I{}_{x} \left(x_{p} + \frac{0.5 \left(x_{p} - 1.
#
#
#
# 0\right)_{p}}\right)}{\frac{RT_{p} \int \epsilon_{s p}_{s p}}\, dxn} + \frac{I
#
#
#
#  I{}_{x}}{\frac{RT_{p} \int \epsilon_{s p}_{s p}}\, dxn} + \int \left(\frac{\l
#
#
#
# eft(2.0 \frac{1}{\hat{T}_{amb} - T{}_{p} j_{scale p}}{j{p}_{p}} + \frac{U_{p}
#
#
#
# - U_{p}_{p}}{dT} \left(T_{amb} - T{}_{s\,p}_{s\,p}_{plus}\right) \left(\frac{1
#
#
#
# }{\hat{T}_{amb} - T{}_{c e p}}{\epsilon_{p}_{e}\, dxn}\right) \right)} + \frac
#
#
#
# {9309419314.30671 C_{e} D_{e}_{concentration scale} l_{n}}{R T{}_{e} \kappa_{e
#
#
#
# } \int \left(\epsilon_{s}_{e s}}\, dxn} - \frac{3103139771.43557 C_{e} D_{e}_{
#
#
#
# concentration scale} l_{n}}{R T{}_{e} \kappa_{e} \int \left(\epsilon_{n}_{e n}
#
#
#
# }\, dxn} - \frac{9309419314.30671 C_{e} D_{e}_{concentration scale} \left(- I
#
#
#
# l_{p} + I\right)}{R T{}_{e} \kappa_{e} \int \left(\epsilon_{s}_{e s}}\, dxn} -
#
#
#
#  \left(1+\frac{dlnf}{dlnc} \frac{1}{\hat{T}_{plus}\right) \left(T_{amb} - T{}_
#
#
#
# {plus}\right)\right) \int \log{\left(\max\left(1.0 \cdot 10_{c e n}}{\epsilon_
#
#
#
# {n}_{e}\, dxn}\right) \right)}\, dxn + \int \frac{0.5 I I{}_{x} \left(- 2.0 l_
#
#
#
# {n} x_{n} + x_{n}_{n} l_{n} \int \epsilon_{s n}_{s n}}\, dxn}\, dxn - \int \le
#
#
#
# ft(\frac{\left(2.0 \frac{1}{\hat{T}_{amb} - T{}_{n} j_{scale n}}{j{n}_{n}} + \
#
#
#
# frac{U_{n} - U_{n}_{n}}{dT} \left(T_{amb} - T{}_{s\,n}_{s\,n}_{e} D_{e}_{conce
#
#
#
# ntration scale} \left(l_{p}_{p}_{p}\right)}{R T{}_{e} \kappa_{e} \int \left(\e
#
#
#
# psilon_{p}_{e p}}\, dxn} - \frac{9309419314.30671 C_{e} D_{e}_{concentration s
#
#
#
# cale}}{R T{}_{e} \kappa_{e} \int \left(\epsilon_{p}_{e p}}\, dxn}\right)}{l_{p
#
#
#
# }}\right)\, dxn__{typ} L__{ref}}{F} \sigma__{b__{typ} L__{2.0}}{l__{ref}}{F} \
#
#
#
# sigma__{b__{typ} L__{ref}}{F} \sigma__{b__{ref}} \left(T__{ref}\right) + 2.0\r
#
#
#
# ight) \operatorname{asinh}{\left(\frac{0.5 j__{0}} \right)}}{ne__{ref} + \frac
#
#
#
# {dU__{ref}\right) + \frac{1.0 \cdot 10__{-6}}{\max\left(1.0 \cdot 10__{-10}, \
#
#
#
# min\left(0.9999999999, \bar{c}__{surf}\right)\right)} + \frac{1.0 \cdot 10__{-
#
#
#
# 6}}{\max\left(1.0 \cdot 10__{-10}, \min\left(0.9999999999, \bar{c}__{surf}\rig
#
#
#
# ht)\right) - 1.0}}{\frac{RT__{ref}}{F}}\right)\, dxn + \int \left(1+\frac{dlnf
#
#
#
# }{dlnc} \left(2.0 - 2.0 t__{ref}} \left(T__{ref}\right) + 1.0\right) \log{\lef
#
#
#
# t(\max\left(1.0 \cdot 10__{-15}, \frac{\epsilon__{init} \int c__{typ} I electr
#
#
#
# olyte__{ref} \gamma__{init}\right)__{b__{typ} I electrolyte__{ref} \gamma__{in
#
#
#
# it}\right)__{b__{typ} electrolyte__{ref} \gamma__{init}\right)__{b__{ref}} \le
#
#
#
# ft(2.0 - 2.0 t__{ref}\right) + 1+\frac{dlnf}{dlnc} \left(2.0 - 2.0 t__{-15}, \
#
#
#
# frac{\epsilon__{init} \int c__{typ} L__{2}\right)}{\frac{RT__{ref}}{F} \sigma_
#
#
#
# _{b__{ref}} \left(T__{ref}\right) + 2.0\right) \operatorname{asinh}{\left(\fra
#
#
#
# c{0.5 j__{0}} \right)}}{ne__{ref} + \frac{dU__{ref}\right) + \frac{1.0 \cdot 1
#
#
#
# 0__{-6}}{\max\left(1.0 \cdot 10__{-10}, \min\left(0.9999999999, \bar{c}__{surf
#
#
#
# }\right)\right)} + \frac{1.0 \cdot 10__{-6}}{\max\left(1.0 \cdot 10__{-10}, \m
#
#
#
# in\left(0.9999999999, \bar{c}__{surf}\right)\right) - 1.0}}{\frac{RT__{ref}}{F
#
#
#
# }}\right)\, dxn - \frac{0.5 \cdot \left(\frac{9309419314.30671 C__{typ} I elec
#
#
#
# trolyte__{2.0} - x__{2} + 2.0 x__{ref} \gamma__{init}\right)__{b__{typ} I elec
#
#
#
# trolyte__{ref} \gamma__{init}\right)__{b__{\mathtt{\text{right}}}⋅\frac{RT__{r
#
#
#
# ef}}{F} + ocv{}__{ref}, \\ \textbf{Parameters and Variables}, \tau = \frac{F L
#
#
#
# _{x} particle_{concentration scale n}}{I{}__{typ}}, I{}__{typ} = \frac{I{}_{cc
#
#
#
# } n_{electrodes parallel}}__{typ}}{A, A_cc = L_{y} L_{z}, Lₓ = L_{n} + L_{p} +
#
#
#
#  L_{s}, C_diff_n = \frac{\tau_{diffusion n}}{\tau}, \tau_diffusion_n = \frac{\
#
#
#
# left(R_{n}_{}}__{typ}\right)__{2.0}}{\hat{D}, R_{n}__{typ} = \iint R_{n}\, dxn
#
#
#
# \, dxn, C_diff_p = \frac{\tau_{diffusion p}}{\tau}, \tau_diffusion_p = \frac{\
#
#
#
# left(R_{p}_{}}__{typ}\right)__{2.0}}{\hat{D}, R_{p}__{typ} = \iint R_{p}\, dxn
#
#
#
# \, dxn, \gammaₑ = \frac{electrolyte_{concentration scale}}{particle_{concentra
#
#
#
# tion scale n}}, a = \begin{cases}\frac{3.0 \epsilon_{s n} j_{n}}{\hat{R}_{} a_
#
#
#
# {n}_{s p} j_{p}}{\hat{R}_{} a_{p}__{typ}}\\0.0\\\frac{3.0 \epsilon__{typ}}\end
#
#
#
# {cases}, jₚ = - \frac{0.333333333333333 I a_{p}_{}\, dxn}{l_{p} \int \epsilon_
#
#
#
# {s p}\, dxn}__{typ} \int \hat{R}, a_{p}__{typ} = \frac{3.0 \iint \epsilon_{s p
#
#
#
# }\, dxn\, dxn}{R_{p}__{typ}}, lₚ = \frac{L_{p}}{L_{x}}, I = \frac{\hat{I} \ope
#
#
#
# ratorname{sign}{\left(I{}__{typ} \right)}}{I{}__{typ}}, jₙ = \frac{0.333333333
#
#
#
# 333333 I a_{n}_{}\, dxn}{l_{n} \int \epsilon_{s n}\, dxn}__{typ} \int \hat{R},
#
#
#
#  a_{n}__{typ} = \frac{3.0 \iint \epsilon_{s n}\, dxn\, dxn}{R_{n}__{typ}}, lₙ
#
#
#
# = \frac{L_{n}}{L_{x}}, Cₑ = \frac{\tau_{diffusion e}}{\tau}, \tau_diffusion_e
#
#
#
# = \frac{L_{x}_{e}__{2.0}}{D__{typ}}, iₑ = \begin{cases}\frac{I x_{n}}{l_{n}}\\
#
#
#
# I\\\frac{- I x_{p} + I}{l_{p}}\end{cases}, cₑ = \begin{cases}\frac{\epsilon_{c
#
#
#
#  e n}}{\epsilon_{n}_{c e s}}{\epsilon_{s}_{c e p}}{\epsilon_{p}__{init}}\\\fra
#
#
#
# c{\epsilon__{init}}\\\frac{\epsilon__{init}}\end{cases}, \epsilon_e}__{b = \be
#
#
#
# gin{cases}\left(\epsilon_{n}_{e n}}\\\left(\epsilon_{s}_{e s}}\\\left(\epsilon
#
#
#
# _{p}_{e p}}\end{cases}__{init}\right)__{b__{init}\right)__{b__{init}\right)__{
#
#
#
# b, L_z = \text{Electrode height [m]}, L_y = \text{Electrode width [m]}, n_elec
#
#
#
# trodes_parallel = \text{Number of electrodes connected in parallel to make a c
#
#
#
# ell}, I{}__{typ} = \text{Typical current [A]}, Lₚ = \text{Positive electrode t
#
#
#
# hickness [m]}, Lₛ = \text{Separator thickness [m]}, Lₙ = \text{Negative electr
#
#
#
# ode thickness [m]}, particle_concentration_scale_n = \text{Maximum concentrati
#
#
#
# on in negative electrode [mol.m-3]}, F = \text{96485.33212}, \hat{I} = \text{C
#
#
#
# urrent function [A]}, \bar{c}_{s\,n} = \text{X-averaged negative particle conc
#
#
#
# entration}, \hat{D}_{} = \text{Negative electrode diffusivity [m2.s-1]}, T{}__
#
#
#
# {ref} = \text{Reference temperature [K]}, Dₙ = \text{Negative electrode diffus
#
#
#
# ivity [m2.s-1]}, T_amb = \text{Ambient temperature [K]}, Rₙ = \text{Negative p
#
#
#
# article radius [m]}, \bar{c}_{s\,p} = \text{X-averaged positive particle conce
#
#
#
# ntration}, \hat{D}_{} = \text{Positive electrode diffusivity [m2.s-1]}, Dₚ = \
#
#
#
# text{Positive electrode diffusivity [m2.s-1]}, Rₚ = \text{Positive particle ra
#
#
#
# dius [m]}, electrolyte_concentration_scale = \text{Typical electrolyte concent
#
#
#
# ration [mol.m-3]}, \epsilonₛ ₚ = \text{Positive electrode active material volu
#
#
#
# me fraction}, \hat{R}_{} = \text{Positive particle radius [m]}, \epsilonₛ ₙ =
#
#
#
# \text{Negative electrode active material volume fraction}, \hat{R}_{} = \text{
#
#
#
# Negative particle radius [m]}, D_{e}__{typ} = \text{Electrolyte diffusivity [m
#
#
#
# 2.s-1]}, tₚₗᵤₛ = \text{Cation transference number}, \epsilon_{p}__{init} = \te
#
#
#
# xt{Positive electrode porosity}, \epsilon_c_e_p = \text{Positive electrode por
#
#
#
# osity times concentration}, \epsilon_{s}__{init} = \text{Separator porosity},
#
#
#
# \epsilon_c_e_s = \text{Separator porosity times concentration}, \epsilon_{n}__
#
#
#
# {init} = \text{Negative electrode porosity}, \epsilon_c_e_n = \text{Negative e
#
#
#
# lectrode porosity times concentration}, Dₑ = \text{Electrolyte diffusivity [m2
#
#
#
# .s-1]}, bₑ ₚ = \text{Positive electrode Bruggeman coefficient (electrolyte)},
#
#
#
# bₑ ₛ = \text{Separator Bruggeman coefficient (electrolyte)}, bₑ ₙ = \text{Nega
#
#
#                                                    ⎤
# tive electrode Bruggeman coefficient (electrolyte)}⎥
#                                                    ⎦

# %% [markdown]
# latexify can also be used to get the equations in a file format like png, jpg, pdf or tex.

# %%
model.latexify("spm_equations.png")

# %% [markdown]
# It will create a png file like this in the directory

# %% [markdown]
# ![SPM Equations PNG](./spm_equations.png)

# %% [markdown]
# Don't worry if you get something like this :)

# %%
model_spme = pybamm.lithium_ion.SPMe()

# %%
model_spme.latexify()
# Out:
# \large{\underline{\textbf{Single Particle Model with electrolyte Equations}}}\\\\\\ \textbf{Discharge capacity [A.h]}\
# \\\\frac{d}{d t} Q = \frac{\hat{I} \tau}{3600}\\\\Q = 0.0\quad at\; t=0\\\\\\ \textbf{X-averaged negative particle con
# centration}\\\\\frac{\partial}{\partial t} \bar{c}_{s,n} = \frac{\nabla\cdot \left(\frac{D_{n} \left(\nabla \bar{c}_{s
# ,n}\right)}{\hat{D}_{n}_{n}}\quad 0 < r < 1\\\\\bar{c}_{s,n} = \frac{c_{n}_{n}_{s,n} = 0.0\quad r = 0\\\\\frac{\partia
# l}{\partial r} \bar{c}_{s,n} = - \frac{C_{n} I}{\frac{D_{n}}{\hat{D}_{n}_{R,n} l_{n}}\quad r = 1\\\\\\ \textbf{X-avera
# ged positive particle concentration}\\\\\frac{\partial}{\partial t} \bar{c}_{s,p} = \frac{\nabla\cdot \left(\nabla \ba
# r{c}_{s,p}\right)}{C_{p}}\quad 0 < r < 1\\\\\bar{c}_{s,p} = \frac{c_{p}_{p}_{s,p} = 0.0\quad r = 0\\\\\frac{\partial}{
# \partial r} \bar{c}_{s,p} = \frac{C_{p} I}{\gamma_{p} a_{R,p} l_{p}}\quad r = 1\\\\\\ \textbf{Porosity times concentra
# tion(Negative electrode porosity times concentration, Separator porosity times concentration, Positive electrode poros
# ity times concentration)}\\\\\frac{\partial}{\partial t} \epsilon_{c e} = \frac{a}{\gamma_{e}} - \frac{\nabla\cdot \le
# ft(\frac{C_{e} i_{e} t_{plus}}{\gamma_{e}} - \frac{D_{e} \epsilon_e} \left(\nabla c_{e}\right)}{D_{e}_{e}}\quad 0 < x
# < 1\\\\\left[ i_{e} = \begin{cases}\frac{I x_{n}}{l_{n}}& 0 < x_{n} < l_n \\ I& l_n < x_{s} < l_n + l_s \\ \frac{I \le
# ft(1.0 - x_{p}\right)}{l_{p}}& l_n + l_s < x_{p} < 1\end{cases}, \  c_{e} = \begin{cases}\frac{\epsilon_{c e n}}{\epsi
# lon_{n}}& 0 < x_{n} < l_n \\ \frac{\epsilon_{c e s}}{\epsilon_{s}}& l_n < x_{s} < l_n + l_s \\ \frac{\epsilon_{c e p}}
# {\epsilon_{p}}& l_n + l_s < x_{p} < 1\end{cases}, \  \epsilon_e} = \begin{cases}\epsilon_{n}_{e n}}& 0 < x_{n} < l_n \
# \ \epsilon_{s}_{e s}}& l_n < x_{s} < l_n + l_s \\ \epsilon_{p}_{e p}}& l_n + l_s < x_{p} < 1\end{cases}\right]\\\\\eps
# ilon_{c e} = \epsilon{}_{e}_{n}_{p}_{x} \left(1.0 - 0.333333333333333 l_{p}\right) \int 1.0\, dxn}{\frac{RT_{p} \int \
# epsilon_{s p}_{e p}}\, dxn} - \frac{I I{}_{x} \left(x_{p} + \frac{0.5 \left(x_{p} - 1.0\right)_{p}}\right) \int 1.0\,
# dxn}{\frac{RT_{p} \int \epsilon_{s p}_{e p}}\, dxn} + \frac{\int \left(- \frac{\left(2.0 \frac{1}{\hat{T}_{amb} - T{}_
# {r p} I \hat{j0}_{p}_{p} j_{0 p} l_{p}} \right)}}{ne_{p}} + \frac{U_{p} - U_{p}_p} \left(T_{amb} - T{}_{s,p}_{s,p}_{pl
# us}\right) \left(\frac{1}{\hat{T}_{amb} - T{}_{c e p} \int 1.0\, dxn}{\epsilon_{p} \int \begin{cases}\frac{\epsilon_{c
#  e n}}{\epsilon_{n}}\\\frac{\epsilon_{c e s}}{\epsilon_{s}}\\\frac{\epsilon_{c e p}}{\epsilon_{p}}\end{cases}\, dxn} \
# right)} - \frac{9309419314.30671 C_{e} D_{e}_{Li}_{p}\right) \int 1.0\, dxn}{R_{const} T{}_{e} \kappa_{e} \int \epsilo
# n_{s}_{e s}}\, dxn} - \frac{4654709657.15335 C_{e} D_{e}_{Li}_{p}_{p} \left(2.0 - x_{p}\right) - 1.0\right) \int 1.0\,
#  dxn}{R_{const} T{}_{e} \kappa_{e} l_{p} \int \epsilon_{p}_{e p}}\, dxn} - \frac{C_{e} I l_{n} \left(- \frac{930941931
# 4.30671 D_{e}_{Li}_{const} T{}_{e} \int \epsilon_{s}_{e s}}\, dxn} + \frac{3103139771.43557 D_{e}_{Li}_{const} T{}_{e}
#  \int \epsilon_{n}_{e n}}\, dxn}\right)}{\gamma_{e}} - \frac{\left(1+\frac{dlnf}{dlnc} \frac{1}{\hat{T}_{plus}\right)
# \left(T_{amb} - T{}_{plus}\right)\right) \int \log{\left(\frac{\epsilon_{c e n} \int 1.0\, dxn}{\epsilon_{n} \int \beg
# in{cases}\frac{\epsilon_{c e n}}{\epsilon_{n}}\\\frac{\epsilon_{c e s}}{\epsilon_{s}}\\\frac{\epsilon_{c e p}}{\epsilo
# n_{p}}\end{cases}\, dxn} \right)}\, dxn}{\int 1.0\, dxn} + \frac{\int \frac{0.5 I I{}_{x} x_{n} \left(- 2.0 l_{n} + x_
# {n}\right) \int 1.0\, dxn}{\frac{RT_{n} l_{n} \int \epsilon_{s n}_{e n}}\, dxn}\, dxn}{\int 1.0\, dxn} - \frac{\int \l
# eft(\frac{\left(2.0 \frac{1}{\hat{T}_{amb} - T{}_{r n} I \hat{j0}_{n}_{0 n} l_{n}} \right)}}{ne_{n}} + \frac{U_{n} - U
# _{n}_n} \left(T_{amb} - T{}_{s,n}_{s,n}_{x} c_{n}_{cc} n_{electrodes parallel}}\\\\A_{cc} = L_{y} L_{z}\\\\L_{x} = L_{
# n} + L_{p} + L_{s}\\\\C_{n} = \frac{\tau_{diffusion n}}{\tau}\\\\\tau_{diffusion n} = \frac{\left(R_{n}_{n}}\\\\C_{p}
# = \frac{\tau_{diffusion p}}{\tau}\\\\\tau_{diffusion p} = \frac{\left(R_{p}_{p}}\\\\\gamma_{e} = \frac{electrolyte_{co
# ncentration scale}}{c_{n}_{s n}}{R_{n} a_{n}_{s p}}{R_{p} a_{p}_{n}}\\0.0\\- \frac{I}{l_{p}}\end{cases}\\\\l_{p} = \fr
# ac{L_{p}}{L_{x}}\\\\I = \hat{I}\\\\l_{n} = \frac{L_{n}}{L_{x}}\\\\a_{p}_{s p}}{R_{p}_{n}_{s n}}{R_{n}_{e} = \frac{\tau
# _{diffusion e}}{\tau}\\\\\tau_{diffusion e} = \frac{L_{x}_{e}_{e} = \begin{cases}\frac{I x_{n}}{l_{n}}\\I\\\frac{I \le
# ft(1.0 - x_{p}\right)}{l_{p}}\end{cases}\\\\c_{e} = \begin{cases}\frac{\epsilon_{c e n}}{\epsilon_{n}}\\\frac{\epsilon
# _{c e s}}{\epsilon_{s}}\\\frac{\epsilon_{c e p}}{\epsilon_{p}}\end{cases}\\\\\epsilon_e} = \begin{cases}\epsilon_{n}_{
# e n}}\\\epsilon_{s}_{e s}}\\\epsilon_{p}_{e p}}\end{cases}\\\\L_{z} = \text{Electrode height [m]}\\\\L_{y} = \text{Ele
# ctrode width [m]}\\\\n_{electrodes parallel} = \text{Number of electrodes connected in parallel to make a cell}\\\\I{}
# _{p} = \text{Positive electrode thickness [m]}\\\\L_{s} = \text{Separator thickness [m]}\\\\L_{n} = \text{Negative ele
# ctrode thickness [m]}\\\\c_{n}_{s\,n} = \text{X-averaged negative particle concentration}\\\\\hat{D}_{n}_{n} = \text{N
# egative electrode diffusivity [m2.s-1]}\\\\T_{amb} = \text{Ambient temperature [K]}\\\\R_{n}_{s\,p} = \text{X-averaged
#  positive particle concentration}\\\\D_{p} = \text{Positive electrode diffusivity [m2.s-1]}\\\\R_{p}_{concentration sc
# ale} = \text{Typical electrolyte concentration [mol.m-3]}\\\\\epsilon_{s p} = \text{Positive electrode active material
#  volume fraction}\\\\R_{p} = \text{Positive particle radius [m]}\\\\\epsilon_{s n} = \text{Negative electrode active m
# aterial volume fraction}\\\\R_{n} = \text{Negative particle radius [m]}\\\\D_{e}_{plus} = \text{Cation transference nu
# mber}\\\\c_{Li}_{p} = \text{Positive electrode porosity}\\\\\epsilon_{c e p} = \text{Positive electrode porosity times
#  concentration}\\\\\epsilon_{s} = \text{Separator porosity}\\\\\epsilon_{c e s} = \text{Separator porosity times conce
# ntration}\\\\\epsilon_{n} = \text{Negative electrode porosity}\\\\\epsilon_{c e n} = \text{Negative electrode porosity
#  times concentration}\\\\D_{e} = \text{Electrolyte diffusivity [m2.s-1]}\\\\b_{e p} = \text{Positive electrode Bruggem
# an coefficient (electrolyte)}\\\\b_{e s} = \text{Separator Bruggeman coefficient (electrolyte)}\\\\b_{e n} = \text{Neg
# ative electrode Bruggeman coefficient (electrolyte)}__{typ}}\right)}{C__{init}}{c__{max}}\quad at\; t=0\\\\\frac{\part
# ial}{\partial r} \bar{c}__{typ}}__{surf} a__{init}}{c__{max}}\quad at\; t=0\\\\\frac{\partial}{\partial r} \bar{c}__{b
# __{typ}}\right)}{C__{b__{b__{b__{b__{init} c__{init}\quad at\; t=0\\\\\\ \textbf{Terminal voltage [V]}\\\\V = - U__{re
# f} + U__{ref} + \frac{I I{}__{typ} L__{ref}}{F} \sigma__{b__{typ} L__{2.0}}{l__{ref}}{F} \sigma__{b__{ref}} \left(T__{
# ref}\right) + 2.0\right) \operatorname{asinh}{\left(\frac{0.5 C__{ref}}{\gamma__{ref} + \frac{dU}{dT__{ref}\right) + \
# frac{1.0 \cdot 10__{-6}}{\bar{c}__{surf} - 1.0} + \frac{1.0 \cdot 10__{-6}}{\bar{c}__{surf}}}{\frac{RT__{ref}}{F}}\rig
# ht)\, dxn}{\int 1.0\, dxn} + \frac{\int \left(1+\frac{dlnf}{dlnc} \left(2.0 - 2.0 t__{ref}} \left(T__{ref}\right) + 1.
# 0\right) \log{\left(\frac{\epsilon__{typ} I c__{typ} \left(1.0 - l__{ref} \gamma__{b__{typ} I c__{typ} \left(l__{2.0}
# + x__{ref} \gamma__{b__{typ} c__{typ} \int 1.0\, dxn}{R__{ref} \kappa__{b__{typ} c__{typ} \int 1.0\, dxn}{R__{ref} \ka
# ppa__{b__{ref}} \left(2.0 - 2.0 t__{ref}\right) + 1+\frac{dlnf}{dlnc} \left(2.0 - 2.0 t__{typ} L__{ref}}{F} \sigma__{b
# __{ref}} \left(T__{ref}\right) + 2.0\right) \operatorname{asinh}{\left(\frac{0.5 C__{ref}}{j__{ref} + \frac{dU}{dT__{r
# ef}\right) + \frac{1.0 \cdot 10__{-6}}{\bar{c}__{surf} - 1.0} + \frac{1.0 \cdot 10__{-6}}{\bar{c}__{surf}}}{\frac{RT__
# {ref}}{F}}\right)\, dxn}{\int 1.0\, dxn}\right)\, dxn}{\int 1.0\, dxn}__{\mathtt{\text{right}}} \frac{RT__{ref}}{F}\\\
# \\\ \textbf{Parameters and Variables}\\\\\tau = \frac{F L__{max}}{I{}__{typ}}\\\\I{}__{typ} = \frac{I{}__{typ}}{A__{ty
# p}\right)__{2.0}}{D__{typ}\right)__{2.0}}{D__{max}}\\\\a = J \begin{cases}\frac{3.0 \epsilon__{typ}}\\0.0\\\frac{3.0 \
# epsilon__{typ}}\end{cases}\\\\J = \begin{cases}\frac{I}{l__{typ} = \frac{3.0 \epsilon__{typ}}\\\\a__{typ} = \frac{3.0
# \epsilon__{typ}}\\\\C__{2.0}}{D__{typ}}\\\\i__{b__{b__{b__{b__{typ} = \text{Typical current [A]}\\\\L__{max} = \text{M
# aximum concentration in negative electrode [mol.m-3]}\\\\F = \text{96485.33212}\\\\\hat{I} = \text{Current function [A
# ]}\\\\\bar{c}__{typ} = \text{Negative electrode diffusivity [m2.s-1]}\\\\T{}__{ref} = \text{Reference temperature [K]}
# \\\\D__{typ} = \text{Negative particle radius [m]}\\\\\bar{c}__{typ} = \text{Positive particle radius [m]}\\\\electrol
# yte__{typ} = \text{Electrolyte diffusivity [m2.s-1]}\\\\t__{typ} = \text{Typical electrolyte concentration [mol.m-3]}\
# \\\\epsilon

# %% [markdown]
# jupyter notebook sometimes cannot render latex output that is too large

# %% [markdown]
# When `newline=False` it returns a list, so it inherits all the properties of a list and you can also do something like this

# %%
model_spme.latexify(newline=False)[15:18]
# Out:
# ⎡d
# ⎢──(\epsilon_c_e) = \frac{a}{\gamma_{e}} - \frac{\nabla\cdot \left(\frac{C_{e} i_{e} t_{plus}}{\gamma_{e}} - \frac{D_{
# ⎣dt
#
#
# e} \epsilon_e} \left(\nabla c_{e}\right)}{D_{e}_{e}}\quad 0 < x < 1__{b__{typ}}\right)}{C, [J = \begin{cases}\frac{I}{
#
#
#
# l_{n}}& 0 < x_{n} < l_n \\ 0.0& l_n < x_{s} < l_n + l_s \\ - \frac{I}{l_{p}}& l_n + l_s < x_{p} < 1\end{cases}, iₑ = \
#
#
#
# begin{cases}\frac{I x_{n}}{l_{n}}& 0 < x_{n} < l_n \\ I& l_n < x_{s} < l_n + l_s \\ \frac{I \left(1.0 - x_{p}\right)}{
#
#
#
# l_{p}}& l_n + l_s < x_{p} < 1\end{cases}, cₑ = \begin{cases}\frac{\epsilon_{c e n}}{\epsilon_{n}}& 0 < x_{n} < l_n \\
#
#
#
# \frac{\epsilon_{c e s}}{\epsilon_{s}}& l_n < x_{s} < l_n + l_s \\ \frac{\epsilon_{c e p}}{\epsilon_{p}}& l_n + l_s < x
#
#
#
# _{p} < 1\end{cases}, \epsilon_e}__{b = \begin{cases}\epsilon_{n}_{e n}}& 0 < x_{n} < l_n \\ \epsilon_{s}_{e s}}& l_n <
#
#
#
#  x_{s} < l_n + l_s \\ \epsilon_{p}_{e p}}& l_n + l_s < x_{p} < 1\end{cases}__{b__{b__{b], \epsilon_{c e} = \epsilon{}_
#
#
#                                    ⎤
# {e}__{init} c__{init}\quad at\; t=0⎥
#                                    ⎦

# %% [markdown]
# ## References
#
# The relevant papers for this notebook are:

# %%
pybamm.print_citations()
# Out:
# [1] Charles R. Harris, K. Jarrod Millman, Stéfan J. van der Walt, Ralf Gommers, Pauli Virtanen, David Cournapeau, Eric Wieser, Julian Taylor, Sebastian Berg, Nathaniel J. Smith, and others. Array programming with NumPy. Nature, 585(7825):357–362, 2020. doi:10.1038/s41586-020-2649-2.
# [2] Scott G. Marquis, Valentin Sulzer, Robert Timms, Colin P. Please, and S. Jon Chapman. An asymptotic derivation of a single particle model with electrolyte. Journal of The Electrochemical Society, 166(15):A3693–A3706, 2019. doi:10.1149/2.0341915jes.
# [3] Valentin Sulzer, Scott G. Marquis, Robert Timms, Martin Robinson, and S. Jon Chapman. Python Battery Mathematical Modelling (PyBaMM). Journal of Open Research Software, 9(1):14, 2021. doi:10.5334/jors.309.
